# %%
#!/usr/bin/env python3


def read_fasta(filename):
    input_file = "../../covid.fasta"
    fasta = open(input_file, 'r')
    print(fasta)
    for line in fasta:
        line = line.strip()
        print(line)

#def read_fasta(filenapme):
 #   with open(../../covid_fasta, 'r') as file:
  #      covid_data = file.read()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 11
#       9         line = line.strip()
#      10         print(line)
# ---> 11 print(line)
#      13 #def read_fasta(filenapme):
#      14  #   with open(../../covid_fasta, 'r') as file:
#      15   #      covid_data = file.read()
#
# NameError: name 'line' is not defined
